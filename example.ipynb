# %%
# !pip install arnie

# %%
from arnie import mfe
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-cac03ea32258> in <cell line: 1>()
# ----> 1 from arnie import mfe
#
# /usr/local/lib/python3.10/dist-packages/arnie/mfe.py in <module>
#       8
#       9 # load package locations from yaml file, watch! global dict
# ---> 10 package_locs = load_package_locations()
#      11
#      12 def mfe(seq, package='vienna_2', T=37,
#
# /usr/local/lib/python3.10/dist-packages/arnie/utils.py in load_package_locations(DEBUG)
#     323     # If the dict is empty, arnie couldn't find packages in the environment variables or arnie file
#     324     if not return_dct:
# --> 325         raise EnvironmentError("No prediction packages found in your environment. Check your environment variables or your ARNIEFILE.")
#     326
# ...

# %% [markdown]
# This error occurs because arnie is unable to find any structure prediction library to use. We'll install EternaFold from the Das Lab which is available via conda-forge.

# %%
# !conda --version
#If !conda --version returns no results, install conda with :
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# Install Eternafold; not available via conda-forge quite yet
# !conda install eternafold -c conda-forge
# !wget https://artprodeus21.artifacts.visualstudio.com/A910fa339-c7c2-46e8-a579-7ea247548706/84710dde-1620-425b-80d0-4cf5baca359d/_apis/artifact/cGlwZWxpbmVhcnRpZmFjdDovL2NvbmRhLWZvcmdlL3Byb2plY3RJZC84NDcxMGRkZS0xNjIwLTQyNWItODBkMC00Y2Y1YmFjYTM1OWQvYnVpbGRJZC83NzI5MTAvYXJ0aWZhY3ROYW1lL2NvbmRhX3BrZ3NfbGludXg1/content?format=zip
# !unzip content\?format\=zip
# !conda install conda_pkgs_linux/eternafold-1.3.1-h00ab1b0_0.conda
# Out:
# --2023-09-07 16:35:01--  https://artprodeus21.artifacts.visualstudio.com/A910fa339-c7c2-46e8-a579-7ea247548706/84710dde-1620-425b-80d0-4cf5baca359d/_apis/artifact/cGlwZWxpbmVhcnRpZmFjdDovL2NvbmRhLWZvcmdlL3Byb2plY3RJZC84NDcxMGRkZS0xNjIwLTQyNWItODBkMC00Y2Y1YmFjYTM1OWQvYnVpbGRJZC83NzI5MTAvYXJ0aWZhY3ROYW1lL2NvbmRhX3BrZ3NfbGludXg1/content?format=zip
# Resolving artprodeus21.artifacts.visualstudio.com (artprodeus21.artifacts.visualstudio.com)... 13.107.42.18, 2620:1ec:21::18
# Connecting to artprodeus21.artifacts.visualstudio.com (artprodeus21.artifacts.visualstudio.com)|13.107.42.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘content?format=zip’
#
# content?format=zip      [   <=>              ]  12.99M  22.1MB/s    in 0.6s
#
# 2023-09-07 16:35:02 (22.1 MB/s) - ‘content?format=zip’ saved [13623485]
#
# Archive:  content?format=zip
#   inflating: conda_pkgs_linux/repodata_from_packages.json.bz2
# ...

# %% [markdown]
# Ordinarily Eternafold will automatically set required environment variables, but environments work a little strangely in colab. We'll set the variables manually here.

# %%
# %env ETERNAFOLD_PATH=/usr/local/bin/eternafold-bin
# %env ETERNAFOLD_PARAMETERS=/usr/local/lib/eternafold-lib/parameters/EternaFoldParams.v1
# Out:
# env: ETERNAFOLD_PATH=/usr/local/bin/eternafold-bin
# env: ETERNAFOLD_PARAMETERS=/usr/local/lib/eternafold-lib/parameters/EternaFoldParams.v1

# %%
from arnie.mfe import mfe
sequence = "CGCUGUCUGUACUUGUAUCAGUACACUGACGAGUCCCUAAAGGACGAAACAGCG"
mfe(sequence,package="eternafold")
# Out:
# '(((((((((((((......))))))..)....((((.....))))...))))))'
